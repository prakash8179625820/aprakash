# %% [markdown]
# Pandas:
# > Used for data manipulation(Data cleaning,Data Organization)
# >Creates Dataframes from excel,csv,txt,DBs
# >Dataframes(Rows and Columns readable by Python)
# >Data cleaning by dropping or replacing with mean
# >Visualize the data

# %%
import pandas as pd

# %% [markdown]
# Series

# %%
names=["Pavan","Shannu","Anil","Sai","Harsha"]
index=[40,42,43,44,45]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40     Pavan
# 42    Shannu
# 43      Anil
# 44       Sai
# 45    Harsha
# dtype: object

# %% [markdown]
# Importing Files
# . for csv and txt : read_csv("file path")
# . for excel : read_excel("file path")

# %%
df=pd.read_csv("/content/diabetcsv.csv",)

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft=pd.read_csv("/content/grades.txt",sep=" ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-46d2504356ff> in <cell line: 1>()
# ----> 1 dft=pd.read_csv("/content/grades.txt",sep=" ")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 0     Joe        K   9.8  10.0   9.9    A+
# 1  Rajesh        M   8.9   9.1   9.3     A
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
print(dft.shape) #get rows and colums
print(dft.shape[0]) #get rows only
print(dft.shape[1]) #get columns only
# Out:
# (16, 6)
# 16
# 6

# %%
dft.columns
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade'], dtype='object')

# %% [markdown]
# 1.   Accessing
# 2.      loc - accepts column names and index
# 3.      iloc - accepts only index

# %%
first_row=dft.iloc[0]
print(first_row)
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Name: 0, dtype: object

# %%
print(dft.loc[2:5]) #to access rows
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+
# 5     Raj        M   8.9   9.1   9.3     A

# %%
print(dft.loc[2:5,"Names"]) #rows of specified columns
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5])
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade
# 2  Kissan        V   9.9   9.3   9.2     A
# 3    Mary        N   7.7   8.0   7.1     B
# 4    Jeen        K   9.8   9.1   9.9    A+

# %%
print(dft.iloc[2:5, :3])
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   NaN     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfn.isnull().head(7)
# Out:
#    Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0  False     False  False  False  False  False   False
# 1  False     False  False  False  False  False   False
# 2  False     False  False  False  False  False   False
# 3  False     False  False  False   True  False   False
# 4  False     False  False  False  False  False   False
# 5  False     False  False  False  False  False   False
# 6  False     False  False  False  False  False   False

# %%
dfn.isnull().sum() #to view how many nulls we have per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()
# Out:
# 4

# %%
dfn.dropna() #dropping all the rows with null
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc=dfn.dropna()

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfn.fillna(5)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(9)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.0   9.1   9.9    A+       1
# 9   Rajini        M   9.0   9.1   9.3     A       0
# 10   Kiran        V   9.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Cleaning with Mean

# %%
me=dfn['SEM3'].mean()
print(me)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(me)
dfc2
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc2.drop_duplicates()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Columns

# %%
dfc2.rename(columns={"Grade":"CGPA"},inplace=True)

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 CGPA  Placed
# 0     Joe        K   9.8  10.0   9.9   A+       1
# 1  Rajesh        M   8.9   9.1   9.3    A       1
# 2  Kissan        V   9.9   9.8  10.0    A       0
# 3    Mary        N   7.7   8.0   9.1    B       0
# 4    Jeen        K   9.8   9.1   9.9   A+       1

# %%
dfc2['Avg_score']=(dfc2['SEM1']+dfc2['SEM2']+dfc2['SEM3'])/3

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 CGPA  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9   A+       1   9.900000
# 1  Rajesh        M   8.9   9.1   9.3    A       1   9.100000
# 2  Kissan        V   9.9   9.8  10.0    A       0   9.900000
# 3    Mary        N   7.7   8.0   9.1    B       0   8.266667
# 4    Jeen        K   9.8   9.1   9.9   A+       1   9.600000

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# Seaborn

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x="Names",y="SEM2",data=dfc2)

# %%
sns.relplot(data=dfc2,x="SEM2",y="SEM1",col="Placed")

# %% [markdown]
# .Load Diabetes
# do replot
# age in x axis,

# %%
 import numpy as np

df['Index'] = np.arange(0,768,1)
sns.relplot(data=df, x="Index", y="age", col="class")

# %%
dfe['Index']=range(1,769)

# %%
dfe.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive      5

# %% [markdown]
# *   Inbuilt data sets seaborn
# *   Dowjones
# *   fmri
# *   dots
# *   healthexp
# *   to load dataset use:load_dataset("tips")
# *   hue - creating difference based on a column via colors
# *   style - different color marking
# *   color palettes - pastel,bright,dark,muted,color_blind,
# *   List item

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips, x="total_bill", y="tip",hue="smoker",style="time")
#hue - creating difference based on a column via colors

# %%
sns.relplot(data=tips, x="total_bill", y="tip",hue="smoker",style="day",palette="dark")

# %%
dowjones=sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data=fmri,x="timepoint",y="signal",kind="line")

# %%
sns.catplot(data=tips,x="total_bill",y="day")

# %%
sns.catplot(data=fmri,x="region",y="timepoint",kind="violin",hue="subject")

# %% [markdown]
# Linearfit-lmplot()
# *   plotting the data
# *   fitting the line
# *   predicting the line

# %%
sns.lmplot(x="size",y="tip",data=tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f2b32996f81d> in <cell line: 1>()
# ----> 1 sns.lmplot(x="size",y="tip",data=tips)
#
# NameError: name 'tips' is not defined

# %% [markdown]
# Web scrapping
#
# *   loading data from websites
# *   unstructed in HTML
# *   convertible into spreadsheets/DB
# *   major websites have their API's for web scrapping
# Scrapper
#
#
# *   Extract all the data on particular sites
#
# *   Specific data that a user wants
# *   Process:
#
#
# *   URL->
# *   HTML code->
#
#
# *   Elements(CSS/JS)
# *   Scrapes the required data->
#
#
# *   Saves the required format(csv,xlsx,Json)
#
#
#
# *   Applications:
#
#
#
#
# *    Email Marketing
#
# *    Sentiments Analysis
# *   News Monitoring
#
#
# *   Market Research
#
# *   Price Monitoring
